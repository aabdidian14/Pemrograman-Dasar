# %% [markdown]
# <a href="https://colab.research.google.com/github/aabdidian14/Pemrograman-Dasar/blob/main/Quiz%20soal%202%20pertemuan%205%20.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
for i in range(200):
    print("Abdidian")
# Out:
# Abdidian
# Abdidian
# Abdidian
# Abdidian
# Abdidian
# Abdidian
# Abdidian
# Abdidian
# Abdidian
# Abdidian
# Abdidian
# Abdidian
# Abdidian
# Abdidian
# Abdidian
# Abdidian
# Abdidian
# Abdidian
# Abdidian
# Abdidian
# Abdidian
# Abdidian
# Abdidian
# Abdidian
# Abdidian
# Abdidian
# Abdidian
# Abdidian
# Abdidian
# Abdidian
# Abdidian
# Abdidian
# Abdidian
# Abdidian
# Abdidian
# Abdidian
# Abdidian
# Abdidian
# Abdidian
# Abdidian
# Abdidian
# Abdidian
# Abdidian
# Abdidian
# Abdidian
# Abdidian
# Abdidian
# Abdidian
# Abdidian
# Abdidian
# Abdidian
# Abdidian
# Abdidian
# Abdidian
# Abdidian
# Abdidian
# Abdidian
# Abdidian
# Abdidian
# Abdidian
# Abdidian
# Abdidian
# Abdidian
# Abdidian
# Abdidian
# Abdidian
# Abdidian
# Abdidian
# Abdidian
# Abdidian
# Abdidian
# Abdidian
# Abdidian
# Abdidian
# Abdidian
# Abdidian
# Abdidian
# Abdidian
# Abdidian
# Abdidian
# Abdidian
# Abdidian
# Abdidian
# Abdidian
# Abdidian
# Abdidian
# Abdidian
# Abdidian
# Abdidian
# Abdidian
# ...
