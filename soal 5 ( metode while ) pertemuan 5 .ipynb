# %% [markdown]
# <a href="https://colab.research.google.com/github/aabdidian14/Pemrograman-Dasar/blob/main/soal%205%20(%20metode%20while%20)%20pertemuan%205%20.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
i = 1
total = 0
while i <= 100:
    if i % 5 == 0:
        total += i
    i += 1
print("Jumlah kelipatan 5 =", total)
# Out:
# Jumlah kelipatan 5 = 1050
